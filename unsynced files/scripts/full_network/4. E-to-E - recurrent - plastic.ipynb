# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.append("../../src/")


import scipy.stats as stats
from tqdm import tqdm
from baseline_network import BaselineNetwork

# %%
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] = 'Arial'

# %%
net = BaselineNetwork(inh_type="co-tuned", E_to_E="on", E_to_I="on", I_to_I="off",
                      plasticity_E_to_E="on", plasticity_E_to_I="off", plasticity_I_to_E="off", plasticity_I_to_I="off",
                      norm=True, set_seed=True, seed=42, 
                      inh_scale=0.6)
net.run()
# Out:
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:637: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# 100%|██████████| 300/300 [00:10<00:00, 28.26it/s]
# 100%|██████████| 840/840 [06:29<00:00,  2.15it/s]

# %%
drift_mag, drift_rate, convergence = net.get_drift_metrics()

# %%
net.plot_drift_metrics(drift_mag, drift_rate, convergence, figsize=(10, 3))

# %%
# Plot drift magnitude vs assigned weight width (vars_ef)

plt.figure(figsize=(6, 4), dpi=200)
plt.scatter(net.vars_ef, drift_mag[-1], color='blue')
plt.xlabel('Assigned Weight Width')
plt.ylabel('Drift Magnitude at day 28')
plt.title('Drift vs Weight Width')
plt.xscale('log')
plt.yscale('log')

plt.show()

# %%
net.plot_weights()
# Out:
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:667: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
net.plot_activity_at_day(10, 90)
# Out:
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:737: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
day = 10
tuning_curves = net.estimate_tuning_curves_at_day(day)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#  12%|█▏        | 62/500 [00:23<02:45,  2.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 day = 10
# ----> 2 tuning_curves = net.estimate_tuning_curves_at_day(day)
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:499, in BaselineNetwork.estimate_tuning_curves_at_day(self, day, probe_sigma)
#     496 tuning_curves_E = np.zeros((self.N, self.n_test_angles))
#     498 for theta_idx, angle in enumerate(tqdm(theta_list)):
# --> 499     r_E, r_I = self.estimate_activity_at_day(angle, day, probe_sigma=probe_sigma)
#     500     tuning_curves_E[:, theta_idx] = r_E
#     502 return tuning_curves_E
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:485, in BaselineNetwork.estimate_activity_at_day(self, theta, day, probe_sigma)
#     482     u_E += dU_E * self.dt
#     483     u_I += dU_I * self.dt
# --> 485     r_E = self.transfer_E(u_E)
#     486     r_I = self.transfer_I(u_I)
#     488 return r_E, r_I
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:217, in BaselineNetwork.transfer_E(self, u)
#     213     weights /= np.sum(weights, axis=0) # normalize each column to sum to 1
#     215     return weights
# --> 217 def transfer_E(self, u):
#     218     return np.maximum(0, u)
#     220 def transfer_I(self, u):
#
# KeyboardInterrupt:

# %%
net.plot_population_tuning_curves(10, offset=0.01)
# Out:
# 100%|██████████| 500/500 [03:49<00:00,  2.18it/s]
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:592: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
