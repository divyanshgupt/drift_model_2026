# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.append("../../src/")


import scipy.stats as stats
from tqdm import tqdm
from baseline_network import BaselineNetwork

# %%
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] = 'Arial'

# %%
net = BaselineNetwork(inh_type="co-tuned", E_to_E="off", E_to_I="off", I_to_I="off",
                      plasticity_E_to_E="off", plasticity_E_to_I="off", plasticity_I_to_E="off", plasticity_I_to_I="off",
                      norm=True, set_seed=True, seed=42, 
                      if_pre_run=True, n_pre_run_stimuli=300,
                      inh_scale=0.3)
net.run()
# Out:
# Mean I to E weight: 0.003
# 0.02448668506109741
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:595: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# 100%|██████████| 840/840 [04:43<00:00,  2.96it/s]

# %%
drift_mag, drift_rate, convergence = net.get_drift_metrics()

# %%
net.plot_drift_metrics(drift_mag, drift_rate, convergence)

# %%
# Plot drift magnitude vs assigned weight width (vars_ef)

plt.figure(figsize=(6, 4), dpi=200)
plt.scatter(net.vars_ef, drift_mag[-1], color='blue')
plt.xlabel('Assigned Weight Width')
plt.ylabel('Drift Magnitude at day 28')
plt.title('Drift vs Weight Width')
plt.xscale('log')
plt.yscale('log')

plt.show()

# %%
tuning_widths_day_0 = net.estimate_tuning_widths_at_day(0)
plt.figure(figsize=(6, 4), dpi=200)
plt.hist(tuning_widths_day_0, bins=20, color='blue', alpha=0.7)
plt.xlabel('Tuning Width at Day 0')
plt.ylabel('Number of Neurons')
plt.title('Distribution of Tuning Widths at Day 0')
plt.show()
# Out:
# 100%|██████████| 500/500 [04:10<00:00,  2.00it/s]

# %%
net.plot_population_tuning_curves(0)
# Out:
#  77%|███████▋  | 384/500 [02:41<00:48,  2.40it/s]

# %%
# Plot POs at day 0 and day 28
plt.figure(figsize=(12, 5), dpi=200)
plt.subplot(1, 2, 1)
plt.hist(net.POs[0], bins=20, color='blue', alpha=0.7)
plt.xlabel('Preferred Orientation at Day 0')
plt.ylabel('Number of Neurons')
plt.title('Distribution of POs at Day 0')

plt.subplot(1, 2, 2)
plt.hist(net.POs[-1], bins=20, color='orange', alpha=0.7)
plt.xlabel('Preferred Orientation at Day 28')
plt.ylabel('Number of Neurons')
plt.title('Distribution of POs at Day 28')
plt.tight_layout()
plt.show()

# %%
# Plot POs at day 0 vs day 28
plt.figure(figsize=(4, 4), dpi=300)
plt.scatter(net.POs[0], net.POs[-1], color='purple', alpha=0.5)
plt.xlabel('PO at Day 0')
plt.ylabel('PO at Day 28')
plt.title('PO at Day 0 vs Day 28')
plt.plot([0, 180], [0, 180], 'k--', alpha=0.5)  # Diagonal line for reference
plt.xlim(0, 180)
plt.ylim(0, 180)
plt.show()

# %%
# # to check how many neurons are masked at each day (i.e. have flat tuning curves)
# for day in [0, 7, 14, 28]:
#     tc = net.estimate_tuning_curves_at_day(day)
#     peak = np.max(tc, axis=1)
#     threshold = 0.05 * np.max(peak)
#     n_masked = np.sum(peak <= threshold)
#     print(f"Day {day}: {n_masked}/{net.N} neurons masked")

# %% [markdown]
# If the number masked grows over time (more neurons losing their tuning as weights diffuse), that confirms the variance is a measurement artifact from weight diffusion, not genuine drift heterogeneity. In that case, a more meaningful quantity to report would be the fraction of neurons that maintain stable tuning rather than drift magnitude averaged over all neurons including those that lost tuning.

# %%
net.plot_activity_at_day(10, 90)
# Out:
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:596: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
day = 10
tuning_curves = net.estimate_tuning_curves_at_day(day)
# Out:
#   3%|▎         | 16/500 [00:13<06:46,  1.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 day = 10
# ----> 2 tuning_curves = net.estimate_tuning_curves_at_day(day)
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:461, in BaselineNetwork.estimate_tuning_curves_at_day(self, day, probe_sigma)
#     458 tuning_curves_E = np.zeros((self.N, self.n_test_angles))
#     460 for theta_idx, angle in enumerate(tqdm(theta_list)):
# --> 461     r_E, r_I = self.estimate_activity_at_day(angle, day, probe_sigma=probe_sigma)
#     462     tuning_curves_E[:, theta_idx] = r_E
#     464 return tuning_curves_E
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:447, in BaselineNetwork.estimate_activity_at_day(self, theta, day, probe_sigma)
#     444     u_E += dU_E * self.dt
#     445     u_I += dU_I * self.dt
# --> 447     r_E = self.transfer_E(u_E)
#     448     r_I = self.transfer_I(u_I)
#     450 return r_E, r_I
#
# File ~/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:198, in BaselineNetwork.transfer_E(self, u)
#     194     weights /= np.sum(weights, axis=0) # normalize each column to sum to 1
#     196     return weights
# --> 198 def transfer_E(self, u):
#     199     return np.maximum(0, u)
#     201 def transfer_I(self, u):
#
# KeyboardInterrupt:

# %%
net.plot_population_tuning_curves(10)
# Out:
# 100%|██████████| 500/500 [22:22<00:00,  2.69s/it]
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/full_network/../../src/baseline_network.py:482: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
cell_idx = 100
plt.figure(dpi=200, figsize=(4,3))
plt.plot(tuning_curves[cell_idx])
plt.title(f"Cell {cell_idx} tuning curve at day {day}")
# Out:
# Text(0.5, 1.0, 'Cell 100 tuning curve at day 10')

# %% [markdown]
# ### Test time varying inh modualation

# %%
net_varying_inh = BaselineNetwork()
