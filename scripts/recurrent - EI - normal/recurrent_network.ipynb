# %%
import sys, os
sys.path.append("../../src/")

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation

import scipy.stats as stats
from tqdm import tqdm
from recurrent_net import recurrent_network
import h5py as h5

# %%
network = recurrent_network(normalization=True)

# %%
network.run()
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 17769.88it/s]

# %%
timestep = 100
network.plot_activity(timestep=timestep)
network.plot_weights(timestep=timestep)
# Out:
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/recurrent - EI - normal/../../src/recurrent_net.py:318: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()
# /Users/divyansh/Library/CloudStorage/GoogleDrive-divyanshg1207@gmail.com/My Drive/Course Stuff/PhD/Projects | PhD/sensory drift/drift_model_2026/scripts/recurrent - EI - normal/../../src/recurrent_net.py:324: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[2].legend()

# %%
timestep = -1
network.plot_activity(timestep=timestep)
network.plot_weights(timestep=timestep)
